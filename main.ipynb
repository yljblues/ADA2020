# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from matplotlib import pyplot as plt

# %% [markdown]
# ## Dataset for Political Power

# %%
# combining the data in each year into one data frame
years = [2010, 2012, 2014, 2016, 2018]
df_political = pd.DataFrame()

for y in years:
    df = pd.read_csv('data/table04b_{}.csv'.format(y), skiprows=3)
    df = df[0:572]
    # unify the column name of the data frame
    columns_name = ['State', 'Race', 'Total population', 'Total citizen population',
               'Total registered', 'Percent registered (Total)', 'Margin of error 1', 'Percent registered (Citizen)',
               'Margin of error 1', 'Total voted', 'Percent voted (Total)', 'Margin of error 1', 'Percent voted (Citizen)',
               'Margin of error 1']
    columns_mapping = {}
    for i in range(len(columns_name)):
        columns_mapping[df.columns[i]] = columns_name[i]
    df = df.rename(columns=columns_mapping)
    df = df[columns_name]
    # change NaN in the row
    for i in range(df.shape[0]):
        if not pd.isna(df['State'][i]):
            state_name = df.loc[i]['State']
        else:
            df.loc[i]['State'] = state_name
    # for the column 'Race', we only need data that is 'total', 'black', 'white', 'hispanic'
    df = df.loc[(df['Race'] == 'Total') | (df['Race'] == 'White alone') | (df['Race'] == 'Black alone') | (df['Race'] == 'Hispanic (of any race)')]
    df.loc[df['Race'] == 'White alone', 'Race'] = 'White'
    df.loc[df['Race'] == 'Black alone', 'Race'] = 'Black'
    df.loc[df['Race'] == 'Hispanic (of any race)', 'Race'] = 'Hispanic'
    # add year to the dataframe
    df.insert(loc=0, column='year', value=[y for _ in range(df.shape[0])])
    # combine the dataframe in each year
    df_political = pd.concat([df_political, df])
df_political[:30]
# Out:
#     year        State      Race Total population Total citizen population  \
# 0   2010           US     Total          229,690                  210,800
# 3   2010           US     White          185,804                  172,447
# 5   2010           US     Black           27,396                   25,632
# 7   2010           US  Hispanic           32,457                   21,285
# 11  2010      ALABAMA     Total            3,526                    3,420
# 14  2010      ALABAMA     White            2,611                    2,521
# 16  2010      ALABAMA     Black              868                      868
# 18  2010      ALABAMA  Hispanic              142                       65
# 22  2010       ALASKA     Total              498                      478
# 25  2010       ALASKA     White              385                      375
# 27  2010       ALASKA     Black               24                       24
# 29  2010       ALASKA  Hispanic               23                       20
# 33  2010      ARIZONA     Total            4,831                    4,443
# 36  2010      ARIZONA     White            4,267                    3,905
# 38  2010      ARIZONA     Black              193                      186
# 40  2010      ARIZONA  Hispanic            1,389                    1,061
# 44  2010     ARKANSAS     Total            2,140                    2,068
# 47  2010     ARKANSAS     White            1,740                    1,701
# 49  2010     ARKANSAS     Black              310                      310
# 51  2010     ARKANSAS  Hispanic               83                       48
# 55  2010   CALIFORNIA     Total           27,381                   22,767
# 58  2010   CALIFORNIA     White           20,828                   17,331
# 60  2010   CALIFORNIA     Black            1,728                    1,661
# 62  2010   CALIFORNIA  Hispanic            9,004                    5,816
# 66  2010     COLORADO     Total            3,768                    3,473
# 69  2010     COLORADO     White            3,423                    3,195
# 71  2010     COLORADO     Black              148                      129
# 73  2010     COLORADO  Hispanic              629                      455
# 77  2010  CONNECTICUT     Total            2,648                    2,463
# 80  2010  CONNECTICUT     White            2,273                    2,181
#
#    Total registered Percent registered (Total) Margin of error 1  \
# 0           137,263                       59.8               0.3
# 3           114,482                       61.6               0.3
# 5            16,101                       58.8                 1
# 7            10,982                       33.8               1.2
# 11            2,224                       63.1               2.4
# 14            1,612                       61.7               2.8
# 16              599                         69               5.6
# 18               34                       23.6              16.5
# 22              317                       63.8               2.5
# 25              262                       68.2               2.8
# 27               13                        (B)               (B)
# 29               10                        (B)               (B)
# 33            2,934                       60.7               2.1
# 36            2,581                       60.5               2.2
# 38              122                       63.1              12.6
# 40              610                       43.9               6.3
# 44            1,256                       58.7               2.5
# 47            1,050                       60.4               2.8
# 49              168                       54.3               8.1
# 51               14                       17.1              15.3
# 55           13,864                       50.6               0.9
# 58           11,016                       52.9                 1
# 60              932                         54               4.4
# 62            3,025                       33.6               2.4
# 66            2,299                         61               2.4
# 69            2,142                       62.6               2.5
# 71               82                       55.6              14.9
# 73              214                         34               8.9
# 77            1,641                         62               2.5
# 80            1,473                       64.8               2.7
#
#    Margin of error 1 Margin of error 1  ... Percent voted (Total)  \
# 0                0.3               0.3  ...                  41.8
# 3                0.3               0.3  ...                  43.4
# 5                  1                 1  ...                  40.7
# 7                1.5                 1  ...                  20.5
# 11               2.4               2.5  ...                  42.8
# 14               2.8               2.8  ...                    42
# 16               5.6                 6  ...                  46.4
# 18              28.6              11.7  ...                  10.2
# 22               2.6               2.6  ...                  48.6
# 25               2.8                 3  ...                  54.3
# 27               (B)               (B)  ...                   (B)
# 29               (B)               (B)  ...                   (B)
# 33               2.1               2.1  ...                  44.9
# 36               2.3               2.3  ...                  45.4
# 38              12.7              12.8  ...                  39.4
# 40               7.2               5.8  ...                  29.3
# 44               2.5               2.5  ...                  39.3
# 47               2.8               2.8  ...                    41
# 49               8.1               7.6  ...                  32.5
# 51              24.4              13.1  ...                  11.8
# 55                 1               0.9  ...                  39.2
# 58               1.1                 1  ...                  41.6
# 60               4.4               4.3  ...                    41
# 62               3.1               2.1  ...                  22.9
# 66               2.4               2.5  ...                  48.4
# 69               2.5               2.6  ...                  50.1
# 71              15.4              14.7  ...                  40.6
# 73              11.1               7.9  ...                  22.9
# 77               2.6               2.6  ...                  45.9
# 80               2.7               2.8  ...                  48.2
#
#    Margin of error 1 Margin of error 1 Margin of error 1 Margin of error 1  \
# 0                0.3               0.3               0.3               0.3
# 3                0.3               0.3               0.3               0.3
# 5                  1                 1                 1               1.1
# 7                1.2               1.5                 1               1.4
# 11               2.4               2.4               2.5               2.5
# 14               2.8               2.8               2.8               2.9
# 16               5.6               5.6                 6                 6
# 18              16.5              28.6              11.7              23.8
# 22               2.5               2.6               2.6               2.7
# 25               2.8               2.8                 3                 3
# 27               (B)               (B)               (B)               (B)
# 29               (B)               (B)               (B)               (B)
# 33               2.1               2.1               2.1               2.3
# 36               2.2               2.3               2.3               2.4
# 38              12.6              12.7              12.8              13.1
# 40               6.3               7.2               5.8                 7
# 44               2.5               2.5               2.5               2.5
# 47               2.8               2.8               2.8               2.8
# 49               8.1               8.1               7.6               7.6
# 51              15.3              24.4              13.1              21.6
# 55               0.9                 1               0.9                 1
# 58                 1               1.1                 1               1.1
# 60               4.4               4.4               4.3               4.4
# 62               2.4               3.1               2.1                 3
# 66               2.4               2.4               2.5               2.6
# 69               2.5               2.5               2.6               2.7
# 71              14.9              15.4              14.7                16
# 73               8.9              11.1               7.9              10.3
# 77               2.5               2.6               2.6               2.7
# 80               2.7               2.7               2.8               2.9
#
#    Percent voted (Citizen) Margin of error 1 Margin of error 1  \
# 0                     45.5               0.3               0.3
# 3                     46.7               0.3               0.3
# 5                     43.5                 1                 1
# 7                     31.2               1.2               1.5
# 11                    44.1               2.4               2.4
# 14                    43.5               2.8               2.8
# 16                    46.4               5.6               5.6
# 18                    22.1              16.5              28.6
# 22                    50.7               2.5               2.6
# 25                    55.7               2.8               2.8
# 27                     (B)               (B)               (B)
# 29                     (B)               (B)               (B)
# 33                    48.8               2.1               2.1
# 36                    49.6               2.2               2.3
# 38                      41              12.6              12.7
# 40                    38.3               6.3               7.2
# 44                    40.7               2.5               2.5
# 47                    41.9               2.8               2.8
# 49                    32.5               8.1               8.1
# 51                    20.5              15.3              24.4
# 55                    47.1               0.9                 1
# 58                      50                 1               1.1
# 60                    42.6               4.4               4.4
# 62                    35.4               2.4               3.1
# 66                    52.6               2.4               2.4
# 69                    53.7               2.5               2.5
# 71                    46.6              14.9              15.4
# 73                    31.7               8.9              11.1
# 77                    49.3               2.5               2.6
# 80                    50.3               2.7               2.7
#
#    Margin of error 1 Margin of error 1
# 0                0.3               0.3
# 3                0.3               0.3
# 5                  1               1.1
# 7                  1               1.4
# 11               2.5               2.5
# 14               2.8               2.9
# 16                 6                 6
# 18              11.7              23.8
# 22               2.6               2.7
# 25                 3                 3
# 27               (B)               (B)
# 29               (B)               (B)
# 33               2.1               2.3
# 36               2.3               2.4
# 38              12.8              13.1
# 40               5.8                 7
# 44               2.5               2.5
# 47               2.8               2.8
# 49               7.6               7.6
# 51              13.1              21.6
# 55               0.9                 1
# 58                 1               1.1
# 60               4.3               4.4
# 62               2.1                 3
# 66               2.5               2.6
# 69               2.6               2.7
# 71              14.7                16
# 73               7.9              10.3
# 77               2.6               2.7
# 80               2.8               2.9
#
# [30 rows x 27 columns]
